# %%
from collections import defaultdict
import os
import csv
import pandas as pd

from xml.etree.ElementTree import parse, Element, SubElement, ElementTree
import xml.etree.ElementTree as ET

# %%
csv_name = 'D://vehicle_data//front_images//merged_output.csv'
df = pd.read_csv(csv_name)
df['class_name'].value_counts()
# Out:
# car              112
# person            43
# np                35
# vehicle_side      18
# vehicle_front     14
# truck             11
# vehicle_back      10
# bus                6
# motorcycle         2
# Name: class_name, dtype: int64

# %%
df = pd.read_csv(csv_name)
ax = df['class_name'].value_counts().plot(kind = 'pie',autopct='%1.1f%%',subplots=True)
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5132\3708845064.py in <module>
#       1 df = pd.read_csv(csv_name)
#       2 ax = df['class_name'].value_counts().plot(kind = 'pie',autopct='%1.1f%%',subplots=True)
# ----> 3 ax.legend()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'legend'

# %%
df['Aspect_ratio'] = (df['y2']-df['y1'])/(df['x2'] - df['x1'])

# %%
df.groupby('class_name')['Aspect_ratio'].mean()
# Out:
# class_name
# bus              1.132387
# car              0.873300
# motorcycle       1.701330
# np               0.466608
# person           2.389184
# truck            0.683540
# vehicle_back     0.943986
# vehicle_front    0.781462
# vehicle_side     0.604219
# Name: Aspect_ratio, dtype: float64

# %%
fig = plt.barh(df.groupby('class_name')['Aspect_ratio'].mean().index,df.groupby('class_name')['Aspect_ratio'].mean())
fig.bar_label(fig.containers[0], label_type='edge')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5132\4061419594.py in <module>
#       1 fig = plt.barh(df.groupby('class_name')['Aspect_ratio'].mean().index,df.groupby('class_name')['Aspect_ratio'].mean())
# ----> 2 fig.bar_label(fig.containers[0], label_type='edge')
#       3 plt.show()
#
# AttributeError: 'BarContainer' object has no attribute 'bar_label'

# %%
df.boxplot(column=['Aspect_ratio'],by='class_name',rot=45)
# Out:
# <AxesSubplot:title={'center':'Aspect_ratio'}, xlabel='class_name'>

# %%
i = 0
for grp_name, df_grp in df.groupby('class_name'):
    i = i+1
    plt.subplot(3,3,i)
    sns.boxplot(y=df_grp['Aspect_ratio'])

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(8, 8))
barchart = sns.barplot(x=df.groupby('class_name')['Aspect_ratio'].mean(), y=df.groupby('class_name')['Aspect_ratio'].mean().index, ax=ax)


barchart.bar_label(ax.containers[0], label_type='edge', padding=15)
piechart = sns.piechart
# Out:
# [Text(15, 0, '1.13239'),
#  Text(15, 0, '0.8733'),
#  Text(15, 0, '1.70133'),
#  Text(15, 0, '0.466608'),
#  Text(15, 0, '2.38918'),
#  Text(15, 0, '0.68354'),
#  Text(15, 0, '0.943986'),
#  Text(15, 0, '0.781462'),
#  Text(15, 0, '0.604219')]

# %%
Human_class = ['person']
Vehicle_class = ['vehicle_back','vehicle_side','vehicle_front','bicycle', 'car', 'motorcycle', 'bus', 'truck','vehicle','np']

# %%
df['Class_type'] = str(Human_class) if df['class_name'].isin(Human_class) else 'vehicle_class'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5132\2673655391.py in <module>
# ----> 1 df['Class_type'] = str(Human_class) if df['class_name'].isin(Human_class) else 'vehicle_class'
#
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df['Class_type'] = df['class_name'].apply(lambda x: 'Human_Class' if x in Human_class else ('Vehicle_class' if x in Vehicle_class else 'New_class'))

# %%
df
# Out:
#                         filename  width  height    class_name   x1   y1   x2  \
# 0                   00000111.jpg    701     434  vehicle_side  200  147  660
# 1           018a011cc5a4474b.jpg    168     114        person   67   27   85
# 2           018a011cc5a4474b.jpg    168     114           bus   12    5  160
# 3           033780299bf24555.jpg    125      90           car   76   15  125
# 4          0350da0bd557c9da2.jpg    209     151           car   13   11  206
# ..                           ...    ...     ...           ...  ...  ...  ...
# 246  VID_20220212_103154 082.jpg    506     262           car    7   16  482
# 247  VID_20220212_103154 082.jpg    506     262  vehicle_back    8    9  207
# 248   VID_20220212_103843 63.jpg    367     250         truck   14   15  362
# 249   VID_20220212_103843 64.jpg    125      95           car    3    6  114
# 250  VID_20220212_120659 053.jpg    129      74           car    7    6  127
#
#       y2  class_confidence  Aspect_ratio     Class_type
# 0    431              0.62      0.617391  Vehicle_class
# 1     44              0.59      0.944444    Human_Class
# 2    107              0.65      0.689189  Vehicle_class
# 3     90              0.53      1.530612  Vehicle_class
# 4    142              0.70      0.678756  Vehicle_class
# ..   ...               ...           ...            ...
# 246  252              0.80      0.496842  Vehicle_class
# 247  254              0.86      1.231156  Vehicle_class
# 248  247              0.53      0.666667  Vehicle_class
# 249   87              0.51      0.729730  Vehicle_class
# 250   68              0.62      0.516667  Vehicle_class
#
# [251 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
for grp_name,df_grp in df.groupby('Class_type'):
    df2 = df_grp['class_name'].value_counts()
    explode = [0.05]*len(df2.index)
    def fmt(x):
        return '{:.0f}'.format(df2.values.sum()*x/100)
    plt.pie(df2,labels=df2.index,explode = explode,pctdistance=0.9, labeldistance=1.1,autopct=fmt)
    plt.legend(bbox_to_anchor=(1.5, 1.0),loc=1)
    plt.title(grp_name)
    plt.tight_layout()
    plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
plt.subplot(121)
barchart = sns.barplot(x=df.groupby('class_name')['Aspect_ratio'].mean(), y=df.groupby('class_name')['Aspect_ratio'].mean().index, ax=ax)


barchart.bar_label(ax.containers[0], label_type='edge', padding=15)
plt.subplot(122)
df2 = df['class_name'].value_counts()
explode = [0.05]*len(df2.index)
def fmt(x):
    return '{:.0f}'.format(df2.values.sum()*x/100)
plt.pie(df2,labels=df2.index,explode = explode,pctdistance=0.9, labeldistance=1.1,autopct=fmt)
plt.legend(bbox_to_anchor=(1.5, 1.0),loc=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5132\2653122020.py in <module>
#       1 fig, ax = plt.subplots(figsize=(8, 8))
#       2 plt.subplot(121)
# ----> 3 barchart = sns.barplot(x=df.groupby('class_name')['Aspect_ratio'].mean(), y=df.groupby('class_name')['Aspect_ratio'].mean().index, ax=ax)
#       4
#       5
#
# d:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# d:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3188         ax = plt.gca()
#    3189
# -> 3190     plotter.plot(ax, kwargs)
#    3191     return ax
#    3192
#
# d:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, bar_kws)
#    1638         """Make the plot."""
#    1639         self.draw_bars(ax, bar_kws)
# -> 1640         self.annotate_axes(ax)
#    1641         if self.orient == "h":
#    1642             ax.invert_yaxis()
#
# d:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in annotate_axes(self, ax)
#     366             ax.set_xticklabels(group_names)
#     367         else:
# --> 368             ax.set_yticks(np.arange(len(self.plot_data)))
#     369             ax.set_yticklabels(group_names)
#     370
#
# d:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      73
#      74         def wrapper(self, *args, **kwargs):
# ---> 75             return get_method(self)(*args, **kwargs)
#      76
#      77         wrapper.__module__ = owner.__module__
#
# d:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in set_ticks(self, ticks, labels, minor, **kwargs)
#    1853         ticks.
#    1854         """
# -> 1855         result = self._set_tick_locations(ticks, minor=minor)
#    1856         if labels is not None:
#    1857             self.set_ticklabels(labels, minor=minor, **kwargs)
#
# d:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _set_tick_locations(self, ticks, minor)
#    1825         else:
#    1826             self.set_major_locator(mticker.FixedLocator(ticks))
# -> 1827             return self.get_major_ticks(len(ticks))
#    1828
#    1829     def set_ticks(self, ticks, labels=None, *, minor=False, **kwargs):
#
# d:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1373         while len(self.majorTicks) < numticks:
#    1374             # Update the new tick label properties from the old.
# -> 1375             tick = self._get_tick(major=True)
#    1376             self.majorTicks.append(tick)
#    1377             self._copy_tick_props(self.majorTicks[0], tick)
#
# d:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2320         else:
#    2321             tick_kw = self._minor_tick_kw
# -> 2322         return YTick(self.axes, 0, major=major, **tick_kw)
#    2323
#    2324     def set_label_position(self, position):
#
# d:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     484             data=([0, 1], [0, 0]), transform=ax.get_yaxis_transform("grid"))
#     485         # the y loc is 3 points below the min of y axis
# --> 486         trans, va, ha = self._get_text1_transform()
#     487         self.label1.set(
#     488             x=0, y=0,
#
# d:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_text1_transform(self)
#     496
#     497     def _get_text1_transform(self):
# --> 498         return self.axes.get_yaxis_text1_transform(self._pad)
#     499
#     500     def _get_text2_transform(self):
#
# d:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in get_yaxis_text1_transform(self, pad_points)
#     961         return (self.get_yaxis_transform(which='tick1') +
#     962                 mtransforms.ScaledTranslation(-1 * pad_points / 72, 0,
# --> 963                                               self.figure.dpi_scale_trans),
#     964                 labels_align, "right")
#     965
#
# AttributeError: 'NoneType' object has no attribute 'dpi_scale_trans'

# %%
df = pd.read_csv(csv_name)
folder_name  = os.path.dirname(csv_name)
save_path = csv_name.split('.')[0]
if not os.path.exists(save_path):
    os.mkdir(save_path)

# %%
df.groupby('class_name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5132\1163545617.py in <module>
# ----> 1 df.groupby('class_name')[0]
#
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1336                 stacklevel=find_stack_level(),
#    1337             )
# -> 1338         return super().__getitem__(key)
#    1339
#    1340     def _gotitem(self, key, ndim: int, subset=None):
#
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     248         else:
#     249             if key not in self.obj:
# --> 250                 raise KeyError(f"Column not found: {key}")
#     251             subset = self.obj[key]
#     252             ndim = subset.ndim
#
# KeyError: 'Column not found: 0'

# %%
df = df.applymap(str)

# %%
df['class_name'].value_counts()

# %%
a = ['car']

# %%
df = df[df['class_name'].isin(a)]

# %%
df['class_name'].value_counts()
# Out:
# car    112
# Name: class_name, dtype: int64

# %%
from tqdm import tqdm
for file_name, df_group in tqdm(df.groupby('filename')):
    root = Element('annotation')
    SubElement(root, 'folder').text = folder_name
    SubElement(root, 'filename').text = file_name
    SubElement(root, 'path').text = './images' + file_name
    source = SubElement(root, 'source')
    SubElement(source, 'database').text = 'Unknown'
    
    size = SubElement(root, 'size')
    SubElement(size, 'width').text = df_group['width'].unique()[0]
    SubElement(size, 'height').text = df_group['height'].unique()[0]
    SubElement(size, 'depth').text = '3'

    SubElement(root, 'segmented').text = '0'
    
    for index, row in df_group.iterrows():
        obj = SubElement(root, 'object')
        SubElement(obj, 'name').text = row['class_name']
        SubElement(obj, 'pose').text = 'Unspecified'
        SubElement(obj, 'truncated').text = '0'
        SubElement(obj, 'difficult').text = '0'

        bbox = SubElement(obj, 'bndbox')
        SubElement(bbox, 'xmin').text = row['x1']
        SubElement(bbox, 'ymin').text = row['x2']
        SubElement(bbox, 'xmax').text = row['y1']
        SubElement(bbox, 'ymax').text = row['y2']
    tree = ElementTree(root)    
    xml_filename = os.path.join(save_path, os.path.splitext(file_name)[0] + '.xml')
    tree.write(xml_filename)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 68/68 [00:00<00:00, 524.37it/s]

# %%
filename	width	height	class_name	x1	y1	x2	y2	class_confidence

# %%
from collections import defaultdict
import os
import csv

from xml.etree.ElementTree import parse, Element, SubElement, ElementTree
import xml.etree.ElementTree as ET

csv_file = 'D://vehicle_data//front_images//merged_output.csv'
class_need = ['bus','car']
folder_name  = os.path.dirname(csv_name)
save_path = csv_name.split('.')[0]

if not os.path.exists(save_path):
    os.mkdir(save_path)


def write_xml(folder, filename, bbox_list):
    root = Element('annotation')
    SubElement(root, 'folder').text = folder
    SubElement(root, 'filename').text = filename
    SubElement(root, 'path').text = './images' + filename
    source = SubElement(root, 'source')
    SubElement(source, 'database').text = 'Unknown'

    size = SubElement(root, 'size')
    SubElement(size, 'width').text = e_width
    SubElement(size, 'height').text = e_height
    SubElement(size, 'depth').text = '3'

    SubElement(root, 'segmented').text = '0'

    for entry in bbox_list:
        e_filename, e_width, e_height, e_class_name, e_xmin, e_ymin, e_xmax, e_ymax, e_confidence = entry

        obj = SubElement(root, 'object')
        SubElement(obj, 'name').text = e_class_name
        SubElement(obj, 'pose').text = 'Unspecified'
        SubElement(obj, 'truncated').text = '0'
        SubElement(obj, 'difficult').text = '0'

        bbox = SubElement(obj, 'bndbox')
        SubElement(bbox, 'xmin').text = e_xmin
        SubElement(bbox, 'ymin').text = e_ymin
        SubElement(bbox, 'xmax').text = e_xmax
        SubElement(bbox, 'ymax').text = e_ymax

    # indent(root)
    tree = ElementTree(root)

    xml_filename = os.path.join('.', folder, os.path.splitext(filename)[0] + '.xml')
    tree.write(xml_filename)


entries_by_filename = defaultdict(list)

with open(csv_file, 'r', encoding='utf-8') as f_input_csv:
    csv_input = csv.reader(f_input_csv)
    header = next(csv_input)
    for row in csv_input:
        filename, width, height, class_name, xmin, ymin, xmax, ymax, class_confidence = row
        if class_name in class_need:
            entries_by_filename[filename].append(row)

for filename, entries in entries_by_filename.items():
    write_xml(save_path, filename, entries)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5132\2619485556.py in <module>
#      63
#      64 for filename, entries in entries_by_filename.items():
# ---> 65     write_xml(save_path, filename, entries)
#
# ~\AppData\Local\Temp\ipykernel_5132\2619485556.py in write_xml(folder, filename, bbox_list)
#      24
#      25     size = SubElement(root, 'size')
# ---> 26     SubElement(size, 'width').text = e_width
#      27     SubElement(size, 'height').text = e_height
#      28     SubElement(size, 'depth').text = '3'
#
# UnboundLocalError: local variable 'e_width' referenced before assignment

# %%
import bagpy
from bagpy import bagreader

b = bagreader('C:/Users/SumeetMitra/Downloads/highway1.bag')
# Out:
# [INFO]  Successfully created the data folder C:/Users/SumeetMitra/Downloads/highway1.

# %%
print(b.topic_table)
# Out:
#              Topics                Types  Message Count  Frequency
# 0  /dvs/cam1/events  dvs_msgs/EventArray          11030  90.895978

# %%
print(dir(b))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'animate_laser', 'animate_pointcloud', 'bagfile', 'clock_data', 'compressed_images', 'datafolder', 'delimiter', 'dir', 'end_time', 'filename', 'frequency', 'laser_data', 'message_by_topic', 'message_types', 'n_messages', 'odometry_data', 'plot_odometry', 'plot_std', 'plot_vel', 'plot_wrench', 'pointcloud_data', 'reader', 'start_time', 'std_data', 'topic_table', 'topic_tuple', 'topics', 'vel_data', 'verbose', 'wrench_data']

# %%
# LASER_MSG = b.message_by_topic('/dvs/cam1/events')
# df_laser = pd.read_csv(LASER_MSG)
# df_laser
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SumeetMitra\AppData\Local\Temp\ipykernel_5132\4220664988.py", line 1, in <module>
#     LASER_MSG = b.message_by_topic('/dvs/cam1/events')
#   File "C:\Users\SumeetMitra\AppData\Roaming\Python\Python39\site-packages\bagpy\bagreader.py", line 270, in message_by_topic
#     for topic, msg, t in self.reader.read_messages(topics=topic, start_time=tstart, end_time=tend):
#   File "C:\Users\SumeetMitra\AppData\Roaming\Python\Python39\site-packages\rosbag\bag.py", line 2705, in read_messages
#     yield self.seek_and_read_message_data_record((entry.chunk_pos, entry.offset), raw, return_connection_header)
#   File "C:\Users\SumeetMitra\AppData\Roaming\Python\Python39\site-packages\rosbag\bag.py", line 2880, in seek_and_read_message_data_record
#     msg.deserialize(data)
#   File "C:\Users\SUMEET~1\AppData\Local\Temp\genpy_dyh9se92\tmpr9ad6pjc.py", line 155, in deserialize
#     val1 = _dvs_msgs__Event()
#   File "C:\Users\SUMEET~1\AppData\Local\Temp\genpy_dyh9se92\tmpr9ad6pjc.py", line 502, in __init__
#     self.ts = genpy.Time()
#   File "C:\Users\SumeetMitra\AppData\Roaming\Python\Python39\site-packages\genpy\rostime.py", line 206, in __init__
#     super(Time, self).__init__(secs, nsecs)
#   File "C:\Users\SumeetMitra\AppData\Roaming\Python\Python39\site-packages\genpy\rostime.py", line 67, in __init__
#     if not isinstance(secs, numbers.Integral):
#   File "d:\ProgramData\Anaconda3\lib\abc.py", line 119, in __instancecheck__
#     return _abc_instancecheck(cls, instance)
#   File "d:\ProgramData\Anaconda3\lib\abc.py", line 123, in __subclasscheck__
#     return _abc_subclasscheck(cls, subclass)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "d:\ProgramData\Anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "d:\ProgramData\Anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "d:\ProgramData\Anaconda3\lib\inspect.py", line 706, in getsourcefile
#     if os.path.exists(filename):
#   File "d:\ProgramData\Anaconda3\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp\ipykernel_5132\4220664988.py in <module>
# ----> 1 LASER_MSG = b.message_by_topic('/dvs/cam1/events')
#       2 df_laser = pd.read_csv(LASER_MSG)
#       3 df_laser
#
# ~\AppData\Roaming\Python\Python39\site-packages\bagpy\bagreader.py in message_by_topic(self, topic)
#     269         time = []
# --> 270         for topic, msg, t in self.reader.read_messages(topics=topic, start_time=tstart, end_time=tend):
#     271             time.append(t)
#
# ~\AppData\Roaming\Python\Python39\site-packages\rosbag\bag.py in read_messages(self, topics, start_time, end_time, connection_filter, raw, return_connection_header)
#    2704         for entry in self.bag._get_entries(connections, start_time, end_time):
# -> 2705             yield self.seek_and_read_message_data_record((entry.chunk_pos, entry.offset), raw, return_connection_header)
#    2706
#
# ~\AppData\Roaming\Python\Python39\site-packages\rosbag\bag.py in seek_and_read_message_data_record(self, position, raw, return_connection_header)
#    2879             msg = msg_type()
# -> 2880             msg.deserialize(data)
#    2881
#
# C:\Users\SUMEET~1\AppData\Local\Temp\genpy_dyh9se92\tmpr9ad6pjc.py in deserialize(self, str)
#     154       for i in range(0, length):
# --> 155         val1 = _dvs_msgs__Event()
#     156         _x = val1
#
# C:\Users\SUMEET~1\AppData\Local\Temp\genpy_dyh9se92\tmpr9ad6pjc.py in __init__(self, *args, **kwds)
#     501       self.y = 0
# --> 502       self.ts = genpy.Time()
#     503       self.polarity = False
#
# ~\AppData\Roaming\Python\Python39\site-packages\genpy\rostime.py in __init__(self, secs, nsecs)
#     205         """
# --> 206         super(Time, self).__init__(secs, nsecs)
#     207         if self.secs < 0:
#
# ~\AppData\Roaming\Python\Python39\site-packages\genpy\rostime.py in __init__(self, secs, nsecs)
#      66         """
# ---> 67         if not isinstance(secs, numbers.Integral):
#      68             # float secs constructor
#
# d:\ProgramData\Anaconda3\lib\abc.py in __instancecheck__(cls, instance)
#     118             """Override for isinstance(instance, cls)."""
# --> 119             return _abc_instancecheck(cls, instance)
#     120
#
# d:\ProgramData\Anaconda3\lib\abc.py in __subclasscheck__(cls, subclass)
#     122             """Override for issubclass(subclass, cls)."""
# --> 123             return _abc_subclasscheck(cls, subclass)
#     124
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2076                         # in the engines. This should return a list of strings.
# -> 2077                         stb = value._render_traceback_()
#    2078                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2077                         stb = value._render_traceback_()
#    2078                     except Exception:
# -> 2079                         stb = self.InteractiveTB.structured_traceback(etype,
#    2080                                             value, tb, tb_offset=tb_offset)
#    2081
#
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# d:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
b.message_types()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5132\4219622478.py in <module>
# ----> 1 b.message_types()
#
# TypeError: 'list' object is not callable

# %%
df_laser
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5132\2432047256.py in <module>
# ----> 1 df_laser
#
# NameError: name 'df_laser' is not defined
